# %%
#Import Neccesary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the csv file into DF
i_df = pd.read_csv(r"C:\Users\User\Desktop\Ashu\Internship_Projects\Task 3\Iris.csv")

# %%
i_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#check for missing values
i_df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# Display percentage of missing values in each column
missing_percentages = (i_df.isnull().mean()*100)
print(missing_percentages)
# Out:
# Id               0.0
# SepalLengthCm    0.0
# SepalWidthCm     0.0
# PetalLengthCm    0.0
# PetalWidthCm     0.0
# Species          0.0
# dtype: float64

# %%
# Check for duplicate rows
i_df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
# Display data types of each column
i_df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
# Check for outliers (basic descriptive statistics)
print("\nDescriptive statistics:")
print(i_df.describe())
# Out:
# Descriptive statistics:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
# Create histograms using seaborn
plt.figure(figsize=(12,8))

# %%
# Histogram for Sepal Length
plt.subplot(2, 2, 1)
sns.histplot(i_df['SepalLengthCm'], bins=20, kde=True, color='blue')
plt.title('Sepal Length Distribution')
# Out:
# Text(0.5, 1.0, 'Sepal Length Distribution')

# %%
# Histogram for Sepal Width
plt.subplot(2, 2, 2)
sns.histplot(i_df['SepalWidthCm'], bins=20, kde=True, color='green')
plt.title('Sepal Width Distribution')
# Out:
# Text(0.5, 1.0, 'Sepal Width Distribution')

# %%
# Histogram for Petal Length
plt.subplot(2, 2, 3)
sns.histplot(i_df['PetalLengthCm'], bins=20, kde=True, color='red')
plt.title('Petal Length Distribution')
# Out:
# Text(0.5, 1.0, 'Petal Length Distribution')

# %%
# Histogram for Petal Width
plt.subplot(2, 2, 4)
sns.histplot(i_df['PetalWidthCm'], bins=20, kde=True, color='purple')
plt.title('Petal Width Distribution')
# Out:
# Text(0.5, 1.0, 'Petal Width Distribution')

# %%
# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
# Calculate the average values of each feature for each species
average_values = i_df.groupby('Species').mean().reset_index()

# %%
# Create a bar chart for each feature
plt.figure(figsize=(12, 8))

# %%
# Bar chart for Sepal Length
plt.subplot(2, 2, 1)
sns.barplot(x='Species', y='SepalLengthCm', data=average_values, hue='Species', dodge=False, palette='Blues', legend=False)
plt.title('Average Sepal Length by Species')
# Out:
# Text(0.5, 1.0, 'Average Sepal Length by Species')

# %%
# Bar chart for Sepal Width
plt.subplot(2, 2, 2)
sns.barplot(x='Species', y='SepalWidthCm', data=average_values, hue='Species', dodge=False, palette='Greens', legend=False)
plt.title('Average Sepal Width by Species')
# Out:
# Text(0.5, 1.0, 'Average Sepal Width by Species')

# %%
# Bar chart for Petal Length
plt.subplot(2, 2, 3)
sns.barplot(x='Species', y='PetalLengthCm', data=average_values, hue='Species', dodge=False, palette='Reds', legend=False)
plt.title('Average Petal Length by Species')
# Out:
# Text(0.5, 1.0, 'Average Petal Length by Species')

# %%
# Bar chart for Petal Width
plt.subplot(2, 2, 4)
sns.barplot(x='Species', y='PetalWidthCm', data=average_values, hue='Species', dodge=False, palette='Purples', legend=False)
plt.title('Average Petal Width by Species')
# Out:
# Text(0.5, 1.0, 'Average Petal Width by Species')

# %%
# Adjust layout and show the plot
plt.tight_layout()
plt.show()
